# %% [markdown]
# ### Q2.21

# %%
a, b = 1, 2

for i in range (3, 101):
    a, b = b, a + b
    
print(f"The 100th term of the Fibonacci sequence is: {b}")
# Out:
# The 100th term of the Fibonacci sequence is: 573147844013817084101

# %% [markdown]
# ![Screenshot_20260218_171026.png](attachment:Screenshot_20260218_171026.png)
