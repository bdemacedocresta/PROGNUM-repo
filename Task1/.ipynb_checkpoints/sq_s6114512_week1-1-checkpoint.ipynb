# %%
Answers for Week 1

Name: Bruno De Macedo Cresta
Username: bmacedo
Student s-number: S6114512
Group: AS2

# %%
X = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7

# %%
number = 1
number *=2
number *=3
number *=4
number *=5
number *=6
print (number)
# Out:
# 720

# %%
import math

# %%
frequency = 2.42 * 10**28
h = 6.626 * 10**-34

Energy = frequency * h

print (Energy)
# Out:
# 1.6034919999999996e-05

# %%
import math

# %%
from scipy.constants import G

# %%
massm = 7.342 * 10**22
masse = 5.9722 * 10**24
r = 385000600

# %%
force = G*( massm * masse )/ (r**2)

# %%
print (force)
# Out:
# 1.974384051807571e+20

# %%
x1 = 10
x2 = 22/7
print (x1, end = "")
print (x2, end = "")
# Out:
# 103.142857142857143

# %% [markdown]
# ### Q1.11

# %% [markdown]
# ![Screenshot%202026-02-12%20at%2012.31.15%E2%80%AFPM.png](attachment:Screenshot%202026-02-12%20at%2012.31.15%E2%80%AFPM.png)

# %% [markdown]
# ### Q1.12

# %% [markdown]
# ![Screenshot%202026-02-12%20at%2012.43.59%E2%80%AFPM.png](attachment:Screenshot%202026-02-12%20at%2012.43.59%E2%80%AFPM.png)

# %% [markdown]
# ### Q1.15

# %% [markdown]
# 1. /Users/users/username/Downloads
# 2. The single dot means the current directory (downloads), and the double dot shows your home directory.

# %% [markdown]
# ### Q 1.16

# %% [markdown]
# cd ~/Desktop

# %% [markdown]
# ### Q 1.19

# %% [markdown]
# ![Screenshot_20260213_101413.png](attachment:Screenshot_20260213_101413.png)

# %% [markdown]
# 1. This command will list any file that has at least one digit between 0-9 anywhere in its name, and ends with a period folowed by either the letter 'c' or 'o'.
# 2. Square brackets are used to match any single character contained within them, like [co] means the position must be exactly one character, in this case either c or o.
# 3. No squares brackets means matching the files containing with the literal two characters 'co' like t3.co. Whereas, with square brackets it will match files containing either c or o.
